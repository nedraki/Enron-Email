# %%
import string
from collections import Counter
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option("display.max_rows", 999)
pd.set_option('max_colwidth',100)
import numpy as np
from IPython.display import display

# %%
# taking csv prepared earlier to explore data 

filepath = "score.csv"
# Read the data into a pandas dataframe called emails

df = pd.read_csv(filepath)

headers = [header for header in df.columns]

print("Successfully loaded {} rows and {} columns!".format(df.shape[0], df.shape[1]))
# Out:
# Successfully loaded 312645 rows and 23 columns!

# %%
df.head(3)
# Out:
#                                                                                             email-body  \
# 0                                                                               Here is our forecast
# 1   Traveling to have a business meeting takes the fun out of the trip.  Especially if you have to ...
# 2                                                                       test successful.  way to go!!!
#
#                       From employee                       Date   Subject  \
# 0  phillip.allen@enron.com  allen-p  2001-05-14 23:39:00+00:00       NaN
# 1  phillip.allen@enron.com  allen-p  2001-05-04 20:51:00+00:00       Re:
# 2  phillip.allen@enron.com  allen-p  2000-10-18 10:00:00+00:00  Re: test
#
#      X-Folder                       To X-cc X-Origin  year  ...     anger  \
# 0  'sent mail     tim.belden@enron.com  NaN  Allen-P  2001  ...  0.100000
# 1  'sent mail  john.lavorato@enron.com  NaN  Allen-P  2001  ...  0.094070
# 2  'sent mail   leah.arsdall@enron.com  NaN  Allen-P  2000  ...  0.083333
#
#     anticip     trust  surprise  positive  negative   sadness   disgust  \
# 0  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 1  0.096115  0.106339  0.089980  0.114519  0.104294  0.100204  0.096115
# 2  0.111111  0.111111  0.083333  0.111111  0.111111  0.111111  0.083333
#
#         joy  topemotion
# 0  0.100000        fear
# 1  0.100204    positive
# 2  0.111111     anticip
#
# [3 rows x 23 columns]

# %% [markdown]
# #  NRCLex lib for emotion score

# %%
from nrclex import NRCLex
# https://pypi.org/project/NRCLex/
'''
NRCLex will measure emotional affect from a body of text. Affect dictionary contains approximately 27,000 words, 
and is based on the National Research Council Canada (NRC)affect lexicon (see link below) 
and the NLTK library's WordNet synonym sets.
'''
# Out:
# "\nNRCLex will measure emotional affect from a body of text. Affect dictionary contains approximately 27,000 words, \nand is based on the National Research Council Canada (NRC)affect lexicon (see link below) \nand the NLTK library's WordNet synonym sets.\n"

# %%
def emotion(x):
    text_object = NRCLex(x)
    fear = text_object.affect_frequencies['fear']
    anger = text_object.affect_frequencies['anger']
    anticip = text_object.affect_frequencies['anticip']
    trust = text_object.affect_frequencies['trust']
    surprise = text_object.affect_frequencies['surprise']
    positive = text_object.affect_frequencies['positive']
    negative = text_object.affect_frequencies['negative']
    sadness = text_object.affect_frequencies['sadness']
    disgust = text_object.affect_frequencies['disgust']
    joy = text_object.affect_frequencies['joy']
    topemotion = text_object.top_emotions[0][0]
    return pd.Series([fear, anger, anticip, trust, surprise, positive, negative, sadness, disgust, joy, topemotion], index=['fear', 'anger', 'anticip', 'trust', 'surprise', 'positive', 'negative', 'sadness', 'disgust', 'joy', 'topemotion'])

# %%
# calling function to get emotion score

#df[['fear', 'anger', 'anticip', 'trust', 'surprise', 'positive', 'negative', 'sadness', 'disgust', 'joy', 'topemotion']] = df['email-body'].swifter.apply(lambda x : emotion(x))

'''
already ran function to add score so no need to run again
'''
# Out:
# '\nalready ran in so no need to run again\n'

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
# Function to add time_hour of mail in features

def hr_func(ts):
    return ts.hour


# calling the function
df['time_hour'] = df['Date'].apply(hr_func)

# %%
### Function for creating class according to hour of a day
### for employee sending or receiving mails reflecting the stress level for work 

def label (row):
    if 9 <= row <= 17: # working hours of a normal office day-- stress level --- "Low"
        return 'Work'
    elif 17 < row <= 21: # working little late to complete work for the day --stress level--- "Medium"
        return 'Evening'
    elif (21 < row) & (row <= 24): # working really late or whole night --- stress level --- "High"
        return 'Night'
    return 'Night'

# %%
## adding the "working-hour" feature by calling the function

df['Work'] = df['time_hour'].apply (lambda row: label(row))

# %%
## having a look at new features

df[['topemotion', 'time_hour', 'Work']].head()
# Out:
#   topemotion  time_hour     Work
# 0       fear         23    Night
# 1   positive         20  Evening
# 2    anticip         10     Work
# 3      trust         13     Work
# 4       fear         12     Work

# %%
##  Ploting stress level over the years 

df.groupby("year")["Work"].value_counts().plot.barh()

# %%
## Plotting the same in Pie chart

data = df.groupby("year")["Work"].value_counts()

pie, ax = plt.subplots(figsize=[16,10])

labels = data.keys()

plt.pie(x=data, autopct="%.1f%%", explode=[0.05]*12, labels=labels, pctdistance=0.9)

plt.title("Work", fontsize=14);

# %%
### Function for plotting the wordcloud on the basis of sentiment analysis 

from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from nltk.corpus import stopwords
import wordcloud


def WC(Folder, stpwords = None):
    
    data = df.loc[df['X-Folder'] == Folder]
     
    
    stop_words = stopwords.words('english')
    
    list_stpwords = ['enron', 'com', 're', 'RECIPIENTS', 'CN', 'ENRON', 'OU', 'NA', 'Thank', 'mail', 'know', 'get', 'Thanks', 'one', 'let', 'cc', 'bc', 'subject', 'http', 'www', 'hotmail', 'email', 'would', 'back', 'time', 'bcc','new', 'aol', 'Com', 'Original Message','message']
    
    if stpwords is True:
        
         list_stpwords.append(stpwords) 
        
        
    stop_words.extend(list_stpwords)

    subjects = ' '.join(data['email-body'])

    fig, ax = plt.subplots(figsize=(16, 12))

    wc = wordcloud.WordCloud(width=800, 
                             height=600, 
                             max_words=200,
                             stopwords=stop_words).generate(subjects)
    ax.imshow(wc)
    ax.axis("off")
    
    plot = ax.imshow(wc)
    
    return plot
# Out:
# /home/becode/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.feature_extraction.stop_words module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_extraction.text. Anything that cannot be imported from sklearn.feature_extraction.text is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
## Calling the function to check how it works

WC('resumes')

# %%
df = df.drop(columns = ['Stress_level'])

# %%
df.head()
# Out:
#                                                                                             email-body  \
# 0                                                                               Here is our forecast
# 1   Traveling to have a business meeting takes the fun out of the trip.  Especially if you have to ...
# 2                                                                       test successful.  way to go!!!
# 3   Randy,  Can you send me a schedule of the salary and level of everyone in the scheduling group....
# 4                                                                    Let's shoot for Tuesday at 11:45.
#
#                       From employee                      Date    Subject  \
# 0  phillip.allen@enron.com  allen-p 2001-05-14 23:39:00+00:00        NaN
# 1  phillip.allen@enron.com  allen-p 2001-05-04 20:51:00+00:00        Re:
# 2  phillip.allen@enron.com  allen-p 2000-10-18 10:00:00+00:00   Re: test
# 3  phillip.allen@enron.com  allen-p 2000-10-23 13:13:00+00:00        NaN
# 4  phillip.allen@enron.com  allen-p 2000-08-31 12:07:00+00:00  Re: Hello
#
#      X-Folder                       To X-cc X-Origin  year  ...     trust  \
# 0  'sent mail     tim.belden@enron.com  NaN  Allen-P  2001  ...  0.100000
# 1  'sent mail  john.lavorato@enron.com  NaN  Allen-P  2001  ...  0.106339
# 2  'sent mail   leah.arsdall@enron.com  NaN  Allen-P  2000  ...  0.111111
# 3  'sent mail    randall.gay@enron.com  NaN  Allen-P  2000  ...  0.142857
# 4  'sent mail     greg.piper@enron.com  NaN  Allen-P  2000  ...  0.000000
#
#    surprise  positive  negative   sadness   disgust       joy  topemotion  \
# 0  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000        fear
# 1  0.089980  0.114519  0.104294  0.100204  0.096115  0.100204    positive
# 2  0.083333  0.111111  0.111111  0.111111  0.083333  0.111111     anticip
# 3  0.095238  0.095238  0.095238  0.095238  0.095238  0.095238       trust
# 4  0.000000  0.250000  0.250000  0.000000  0.000000  0.000000        fear
#
#    time_hour     Work
# 0         23    Night
# 1         20  Evening
# 2         10     Work
# 3         13     Work
# 4         12     Work
#
# [5 rows x 25 columns]

# %%
data = df.groupby("year")["Stress_level"].value_counts(normalize  = True)

# %%
data
# Out:
# year  Stress_level
# 1999  Low             0.774051
#       High            0.122765
#       Medium          0.103184
# 2000  Low             0.776470
#       High            0.133047
#       Medium          0.090483
# 2001  Low             0.540557
#       Medium          0.233727
#       High            0.225716
# 2002  Low             0.426329
#       Medium          0.305316
#       High            0.268355
# Name: Stress_level, dtype: float64

# %%
### making small datasets for selected  Folder basis to see emotion score for the employees for deployment purpose

HR = df.loc[df['X-Folder'] == 'hr']
KPMG = df.loc[df['X-Folder'] == 'kpmg']
Management = df.loc[df['X-Folder'] == 'management']
Resume = df.loc[df['X-Folder'] == 'resumes']
IT = df.loc[df['X-Folder'] == 'it']
Friends = df.loc[df['X-Folder'] == 'myfriends']
Personal = df.loc[df['X-Folder'] == 'personalfolder']
Interviews = df.loc[df['X-Folder'] == 'interviews']
Federal = df.loc[df['X-Folder'] == 'federal legislation']
Personal2 = df.loc[df['X-Folder'] == 'personal']

# %%
Personal2 = df.loc[df['X-Folder'] == 'personal']
Personal2.to_csv('prsnl.csv', index = False)

# %%
Managment
# Out:
#                                                                                                  email-body  \
# 131782   Vince,  I am planning to make my resignation from Enron so that June 5th would be my last day a...
# 131783  X-Folder: \vkamins\c:\mangmt\group\Management X-Origin: KAMINSKI-V X-FileName: vincent kaminski ...
# 131784  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131785  bob.lee@enron.com, gwyn.koepke@enron.com, hector.campos@enron.com, shirley.crenshaw@enron.com, y...
# 131786  shirley.crenshaw@enron.com, youyi.feng@enron.com, praveen.mellacheruvu@enron.com, stephen.bennet...
# 131787  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Margaret,  Thanks for reminding m...
# 131788  X-Origin: Kaminski-V X-FileName: vkamins.nsf  Norma:  you are correct in that Sevil and I have s...
# 131789  bob.lee@enron.com, gwyn.koepke@enron.com, hector.campos@enron.com, shirley.crenshaw@enron.com, y...
# 131790   Vince, Thanks for initiating this information flow. I think the confusion is coming from the qu...
# 131791  X-Origin: Kaminski-V X-FileName: vkamins.nsf  Sevil,  I believe you and Margret Daffin have spok...
# 131792  mike.roberts@enron.com, osman.sezgen@enron.com, vasant.shanbhogue@enron.com, william.smith@enron...
# 131793   Vince:  Can you tell me where to get this info?   ---------------------- Forwarded by Shirley C...
# 131794  jana.giovannini@enron.com, vince.kaminski@enron.com, stinson.gibner@enron.com X-From: Vince J Ka...
# 131795  X-Origin: Kaminski-V X-FileName: vkamins.nsf  Thanks Margaret.  Will keep you in the loop if thi...
# 131796  X-Origin: Kaminski-V X-FileName: vkamins.nsf  Sandeep:  further to my voice mail to you today, I...
# 131797  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Molly,  Giuseppe is finishing his...
# 131798  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131799  X-Origin: Kaminski-V X-FileName: vkamins.nsf  Dear Toni:  Please arrange a payment of $10,000 to...
# 131800  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131801  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Sevil,  Please, make sure you pro...
# 131802  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131803  X-Origin: Kaminski-V X-FileName: vkamins.nsf  Discussions with Lance during his hire were intend...
# 131804  harsimran.singh@enron.com X-From: Margaret Daffin X-To: anshuman.srivastav@enron.com X-cc: Molly...
# 131805  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131806  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Anne,  Thanks.  Vince    From:\tA...
# 131807  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131808  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131809   Sounds great--  Molly     Vince J Kaminski 01/19/2001 06:21 PM To: Molly Magee/HOU/ECT@ECT cc: ...
# 131810  X-Origin: Kaminski-V X-FileName: vkamins.nsf  Molly:  just to be sure that everyone understands,...
# 131811  X-bcc: X-Folder: \vkamins\c:\mangmt\group\Management X-Origin: KAMINSKI-V X-FileName: vincent ka...
# 131812  X-bcc: X-Folder: \vkamins\c:\mangmt\group\Management X-Origin: KAMINSKI-V X-FileName: vincent ka...
# 131813  X-Origin: Kaminski-V X-FileName: vkamins.nsf  Please incease the bonus for Hrgovcic in Vince Kam...
# 131814  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Pat:  Recently, I talked with you...
# 131815  Bcc: anita.dupont@enron.com, vince.kaminski@enron.com X-From: Vasant Shanbhogue X-To: Rakesh Bha...
# 131816  sofya.tamarchenko@enron.com, bob.lee@enron.com, gwyn.koepke@enron.com, hector.campos@enron.com, ...
# 131817  X-cc: Vince J Kaminski X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Grou...
# 131818  jeffrey.shankman@enron.com, jennifer.fraser@enron.com, chris.mahoney@enron.com, annette.harris@e...
# 131819   Vince-  I got your message (I was up on the roof of the building helping to fix the weather sat...
# 131820  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131821  X-cc: X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Or...
# 131822   Vince,  Thanks.  -- Gwyn     Vince J Kaminski@ECT 05/02/2001 03:20 PM To:\tGwyn Koepke/NA/Enron...
# 131823  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Molly,  We would like to bring th...
# 131824   Vince,  Do you want me to do this, or Vasant?  --Stinson  ---------------------- Forwarded by S...
# 131825  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131826   Vince:  I'm sure that you are already aware of this, but I wanted to forward it to you since th...
# 131827  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Hi Norma,  Sevil's primary projec...
# 131828  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131829  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Martin,  I don't  see any problem...
# 131830  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131831  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131832  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131833  X-bcc: X-Folder: \vkamins\c:\mangmt\group\Management X-Origin: KAMINSKI-V X-FileName: vincent ka...
# 131834  X-To: Lance Cunningham, Amitava Dhar, Tom Halliburton, Joseph Hrgovcic, Alex Huang, Kevin Kindal...
# 131835  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst   Christian,  Our Spring/Fall wind...
# 131836  shirley.crenshaw@enron.com, youyi.feng@enron.com, praveen.mellacheruvu@enron.com, stephen.bennet...
# 131837  michael.schilmoeller@enron.com, anita.dupont@enron.com, hector.campos@enron.com, youyi.feng@enro...
# 131838   I will see you on Friday at 3.  If you would like for me to come before then, just let me know....
# 131839  elena.chilkina@enron.com, sofya.tamarchenko@enron.com, sevil.yaman@enron.com, gwyn.koepke@enron....
# 131840  X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: Kaminsk...
# 131841  X-From: Norma Villarreal X-To: Shirley Tijerina, Shirley Crenshaw, Sharon Purswell, Janette Elbe...
# 131842  Mime-Version: 1.0 Content-Type: text/plain; charset=us-ascii Content-Transfer-Encoding: 7bit Bcc...
# 131843  X-To: Vince J Kaminski X-cc: John J Lavorato, Jeffrey A Shankman, Hunter S Shively, Shelly Butle...
# 131844  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131845  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131846  X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: Kaminsk...
# 131847  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 
X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Shirley,  I have been summoned fo...
# 131904  X-Origin: Kaminski-V X-FileName: VKAMINS (Non-Privileged).pst  Anne,  Thanks for contacting me a...
# 131905  X-Origin: Kaminski-V X-FileName: VKAMINS (Non-Privileged).pst  Anne,  Thanks. Shirley is checkin...
# 131906  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131907  X-bcc: X-Folder: \VKAMINS (Non-Privileged)\Kaminski, Vince J\c:\mangmt\group\Management X-Origin...
# 131908  shirley.crenshaw@enron.com, youyi.feng@enron.com, praveen.mellacheruvu@enron.com, stephen.bennet...
# 131909  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Yes Tony , Mike authorized you fo...
# 131910  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131911  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131912  X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: Kaminsk...
# 131913  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Management X-Origin: ...
# 131914  anita.dupont@enron.com, youyi.feng@enron.com, praveen.mellacheruvu@enron.com, stephen.bennett@en...
# 131915  Content-Type: text/plain; charset=us-ascii Content-Transfer-Encoding: 7bit Bcc: vince.kaminski@e...
# 131916  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst   Chris,  FEA just released a new ...
# 131917  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Joe,  We are extremely pleased wi...
# 131918  martin.lin@enron.com X-From: Michael Wilks X-To: Richard Lewis X-cc: Vince J Kaminski, Richard L...
# 131919   Vince,  Here is my edited version of the software license agreement.    Can you read it once be...
# 131920  kirstee.hewitt@enron.com, matthew.williams@enron.com, elena.chilkina@enron.com, sevil.yaman@enro...
# 131921   Vince,  Durasoft (who just taught the Java class for our group) offers a 3-day short course in ...
# 131922  sofya.tamarchenko@enron.com, bob.lee@enron.com, gwyn.koepke@enron.com, hector.campos@enron.com, ...
# 131923  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst   Vince and Stinson,  I did some r...
# 131924    Dear  Vincent Kaminski,  Welcome to Energy News Live - http://www.energynewslive.com !  You ar...
# 131925    ---------------------- Forwarded by Stinson Gibner/HOU/ECT on 04/11/2001 01:13 PM ------------...
# 131926  X-To: Vince J Kaminski X-cc: Vince J Kaminski, Richard Lewis, Tim Belden, tim.heizenrader@enron....
# 131927  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131928  sofya.tamarchenko@enron.com, bob.lee@enron.com, gwyn.koepke@enron.com, hector.campos@enron.com, ...
# 131929  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Jim,  CHARM looks more like  a pr...
# 131930  lloyd.fleming@enron.com X-From: Rodrigo Lamas X-To: Ted Murphy, David Port, Bjorn Hagelmann X-cc...
# 131931  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Vince:  The IT Migration team cal...
# 131932  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131933  X-Folder: \vkamins\c:\mangmt\group\software\Management X-Origin: KAMINSKI-V X-FileName: vincent ...
# 131934  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131935   Friends:  I spoken with most of you over the last few weeks regarding the new version of AURORA...
# 131936  X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Software\Management X-Origin...
# 131937  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst       Outlook Migration Team@ENRON...
# 131938     Return-Path: <dtallam@numerix.com> Received: from  rly-yc04.mx.aol.com (rly-yc04.mail.aol.com...
# 131939  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131940     Return-Path: <Alex.Huang@enron.com> Received: from  rly-yc05.mx.aol.com (rly-yc05.mail.aol.co...
# 131941  Mime-Version: 1.0 Content-Type: text/plain; charset=us-ascii Content-Transfer-Encoding: 7bit X-F...
# 131942  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131943  shalesh.ganjoo@enron.com, tom.halliburton@enron.com, elena.chilkina@enron.com, cantekin.dincerle...
# 131944  X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Software\Management X-Origin...
# 131945  X-cc: Clayton Vernon, Emmanuel Mangin, Vince J Kaminski X-bcc: X-Folder: \Vincent_Kaminski_Jun20...
# 131946  sofya.tamarchenko@enron.com, stinson.gibner@enron.com, tanya.tamarchenko@enron.com, tom.barkley@...
# 131947  X-To: Pinnamaneni Krishnarao X-cc: Chonawee Supatgiat, Grant Masson, Stinson Gibner, Tom Hallibu...
# 131948  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131949  X-To: Ravi Thuraisingham X-cc: Chonawee Supatgiat, Pinnamaneni Krishnarao, samer_takriti@enron.n...
# 131950  X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Software\Management X-Origin...
# 131951  Content-Type: text/plain; charset=us-ascii Content-Transfer-Encoding: 7bit Bcc: mark.breese@enro...
# 131952  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131953  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131954  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131955  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131956  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131957  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131958  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_9\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131959  sofya.tamarchenko@enron.com, stinson.gibner@enron.com, tanya.tamarchenko@enron.com, tom.barkley@...
# 131960  sofya.tamarchenko@enron.com, stinson.gibner@enron.com, tanya.tamarchenko@enron.com, tom.barkley@...
# 131961  sofya.tamarchenko@enron.com, stinson.gibner@enron.com, tanya.tamarchenko@enron.com, tom.barkley@...
# 131962  sofya.tamarchenko@enron.com, stinson.gibner@enron.com, tanya.tamarchenko@enron.com, tom.barkley@...
# 131963  sofya.tamarchenko@enron.com, stinson.gibner@enron.com, tanya.tamarchenko@enron.com, tom.barkley@...
# 131964  sofya.tamarchenko@enron.com, stinson.gibner@enron.com, tanya.tamarchenko@enron.com, tom.barkley@...
# 131965  X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Software\Management X-Origin...
# 131966  sofya.tamarchenko@enron.com, stinson.gibner@enron.com, tanya.tamarchenko@enron.com, tom.barkley@...
# 131967  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131968   I gave you local admin rights on your laptop yesterday. What you have to do is to log into the ...
# 131969  X-bcc: X-Folder: \Vincent_Kaminski_Jun2001_5\Notes Folders\C:\Mangmt\Group\Software\Management X...
# 131970  Content-Type: text/plain; charset=us-ascii Content-Transfer-Encoding: 7bit X-From: Stinson Gibne...
# 131971  X-Origin: KAMINSKI-V X-FileName: vincent kaminski 1-30-02.pst  Phillip,  How can I install new p...
# 131972  Content-Type: text/plain; charset=us-ascii Content-Transfer-Encoding: 7bit Bcc: vince.kaminski@e...
# 131973  X-To: Moyez Lallani X-cc: Vasant Shanbhogue, Vince J Kaminski, Zimin Lu, Maureen Raymond, Pinnam...
# 131974   I will check with Michael and see if it's feasible to do a quick evaluation of his software her...
#
#                                     From    employee  \
# 131782          stinson.gibner@enron.com  kaminski-v
# 131783               iris.mack@enron.com  kaminski-v
# 131784        shirley.crenshaw@enron.com  kaminski-v
# 131785            anita.dupont@enron.com  kaminski-v
# 131786           kevin.kindall@enron.com  kaminski-v
# 131787             sevil.yaman@enron.com  kaminski-v
# 131788         margaret.daffin@enron.com  kaminski-v
# 131789          vince.kaminski@enron.com  kaminski-v
# 131790             sevil.yaman@enron.com  kaminski-v
# 131791        norma.villarreal@enron.com  kaminski-v
# 131792        shirley.crenshaw@enron.com  kaminski-v
# 131793        shirley.crenshaw@enron.com  kaminski-v
# 131794          vince.kaminski@enron.com  kaminski-v
# 131795           sandeep.kohli@enron.com  kaminski-v
# 131796         margaret.daffin@enron.com  kaminski-v
# 131797          stinson.gibner@enron.com  kaminski-v
# 131798          stinson.gibner@enron.com  kaminski-v
# 131799  pinnamaneni.krishnarao@enron.com  kaminski-v
# 131800          vince.kaminski@enron.com  kaminski-v
# 131801          vince.kaminski@enron.com  kaminski-v
# 131802          vince.kaminski@enron.com  kaminski-v
# 131803        norma.villarreal@enron.com  kaminski-v
# 131804         margaret.daffin@enron.com  kaminski-v
# 131805          vince.kaminski@enron.com  kaminski-v
# 131806          vince.kaminski@enron.com  kaminski-v
# 131807         margaret.daffin@enron.com  kaminski-v
# 131808         margaret.daffin@enron.com  kaminski-v
# 131809             molly.magee@enron.com  kaminski-v
# 131810         margaret.daffin@enron.com  kaminski-v
# 131811          vince.kaminski@enron.com  kaminski-v
# 131812       tanya.tamarchenko@enron.com  kaminski-v
# 131813        norma.villarreal@enron.com  kaminski-v
# 131814            anita.dupont@enron.com  kaminski-v
# 131815       vasant.shanbhogue@enron.com  kaminski-v
# 131816        shirley.crenshaw@enron.com  kaminski-v
# 131817          vince.kaminski@enron.com  kaminski-v
# 131818            mike.roberts@enron.com  kaminski-v
# 131819          clayton.vernon@enron.com  kaminski-v
# 131820            mike.roberts@enron.com  kaminski-v
# 131821  pinnamaneni.krishnarao@enron.com  kaminski-v
# 131822             gwyn.koepke@enron.com  kaminski-v
# 131823          vince.kaminski@enron.com  kaminski-v
# 131824          stinson.gibner@enron.com  kaminski-v
# 131825          vince.kaminski@enron.com  kaminski-v
# 131826             molly.magee@enron.com  kaminski-v
# 131827       vasant.shanbhogue@enron.com  kaminski-v
# 131828          vince.kaminski@enron.com  kaminski-v
# 131829          vince.kaminski@enron.com  kaminski-v
# 131830          vince.kaminski@enron.com  kaminski-v
# 131831        lance.cunningham@enron.com  kaminski-v
# 131832        norma.villarreal@enron.com  kaminski-v
# 131833                zimin.lu@enron.com  kaminski-v
# 131834       vasant.shanbhogue@enron.com  kaminski-v
# 131835            mike.roberts@enron.com  kaminski-v
# 131836            anita.dupont@enron.com  kaminski-v
# 131837             anjam.ahmad@enron.com  kaminski-v
# 131838              anne.labbe@enron.com  kaminski-v
# 131839        shirley.crenshaw@enron.com  kaminski-v
# 131840             kevin.moore@enron.com  kaminski-v
# 131841        norma.villarreal@enron.com  kaminski-v
# 131842           samer_takriti@enron.net  kaminski-v
# 131843         jana.giovannini@enron.com  kaminski-v
# 131844          vince.kaminski@enron.com  kaminski-v
# 131845          vince.kaminski@enron.com  kaminski-v
# 131846        shirley.crenshaw@enron.com  kaminski-v
# 131847        shirley.crenshaw@enron.com  kaminski-v
# 131848        shirley.crenshaw@enron.com  kaminski-v
# 131849          vince.kaminski@enron.com  kaminski-v
# 131850        shirley.crenshaw@enron.com  kaminski-v
# 131851        shirley.crenshaw@enron.com  kaminski-v
# 131852             kevin.moore@enron.com  kaminski-v
# 131853        shirley.crenshaw@enron.com  kaminski-v
# 131854          vince.kaminski@enron.com  kaminski-v
# 131855        shirley.crenshaw@enron.com  kaminski-v
# 131856          vince.kaminski@enron.com  kaminski-v
# 131857        shirley.crenshaw@enron.com  kaminski-v
# 131858        shirley.crenshaw@enron.com  kaminski-v
# 131859        shirley.crenshaw@enron.com  kaminski-v
# 131860        shirley.crenshaw@enron.com  kaminski-v
# 131861        shirley.crenshaw@enron.com  kaminski-v
# 131862             kevin.moore@enron.com  kaminski-v
# 131863          vince.kaminski@enron.com  kaminski-v
# 131864          vince.kaminski@enron.com  kaminski-v
# 131865        shirley.crenshaw@enron.com  kaminski-v
# 131866        shirley.crenshaw@enron.com  kaminski-v
# 131867        shirley.crenshaw@enron.com  kaminski-v
# 131868                zimin.lu@enron.com  kaminski-v
# 131869              anne.labbe@enron.com  kaminski-v
# 131870          vince.kaminski@enron.com  kaminski-v
# 131871        shirley.crenshaw@enron.com  kaminski-v
# 131872                zimin.lu@enron.com  kaminski-v
# 131873               iris.mack@enron.com  kaminski-v
# 131874        shirley.crenshaw@enron.com  kaminski-v
# 131875        shirley.crenshaw@enron.com  kaminski-v
# 131876              liz.taylor@enron.com  kaminski-v
# 131877             sevil.yaman@enron.com  kaminski-v
# 131878        shirley.crenshaw@enron.com  kaminski-v
# 131879           erica.beltran@enron.com  kaminski-v
# 131880      ravi.thuraisingham@enron.com  kaminski-v
# 131881          stinson.gibner@enron.com  kaminski-v
# 131882       tanya.tamarchenko@enron.com  kaminski-v
# 131883              alex.huang@enron.com  kaminski-v
# 131884  pinnamaneni.krishnarao@enron.com  kaminski-v
# 131885            grant.masson@enron.com  kaminski-v
# 131886          steven.leppard@enron.com  kaminski-v
# 131887        shirley.crenshaw@enron.com  kaminski-v
# 131888         margaret.daffin@enron.com  kaminski-v
# 131889        shirley.crenshaw@enron.com  kaminski-v
# 131890      ravi.thuraisingham@enron.com  kaminski-v
# 131891          vince.kaminski@enron.com  kaminski-v
# 131892        shirley.crenshaw@enron.com  kaminski-v
# 131893        shirley.crenshaw@enron.com  kaminski-v
# 131894          steven.leppard@enron.com  kaminski-v
# 131895       tanya.tamarchenko@enron.com  kaminski-v
# 131896          stinson.gibner@enron.com  kaminski-v
# 131897        shirley.crenshaw@enron.com  kaminski-v
# 131898            mike.roberts@enron.com  kaminski-v
# 131899        martina.angelova@enron.com  kaminski-v
# 131900        shirley.crenshaw@enron.com  kaminski-v
# 131901        shirley.crenshaw@enron.com  kaminski-v
# 131902          vince.kaminski@enron.com  kaminski-v
# 131903          stinson.gibner@enron.com  kaminski-v
# 131904          vince.kaminski@enron.com  kaminski-v
# 131905          vince.kaminski@enron.com  kaminski-v
# 131906                zimin.lu@enron.com  kaminski-v
# 131907          vince.kaminski@enron.com  kaminski-v
# 131908            anita.dupont@enron.com  kaminski-v
# 131909             kevin.moore@enron.com  kaminski-v
# 131910        charlene.jackson@enron.com  kaminski-v
# 131911            amitava.dhar@enron.com  kaminski-v
# 131912          vince.kaminski@enron.com  kaminski-v
# 131913            anita.dupont@enron.com  kaminski-v
# 131914        shirley.crenshaw@enron.com  kaminski-v
# 131915        shirley.crenshaw@enron.com  kaminski-v
# 131916                zimin.lu@enron.com  kaminski-v
# 131917          vince.kaminski@enron.com  kaminski-v
# 131918           michael.wilks@enron.com  kaminski-v
# 131919          stinson.gibner@enron.com  kaminski-v
# 131920          elena.chilkina@enron.com  kaminski-v
# 131921          stinson.gibner@enron.com  kaminski-v
# 131922         joseph.hrgovcic@enron.com  kaminski-v
# 131923                zimin.lu@enron.com  kaminski-v
# 131924        ecenter@energynewslive.com  kaminski-v
# 131925          stinson.gibner@enron.com  kaminski-v
# 131926            kevin.presto@enron.com  kaminski-v
# 131927          vince.kaminski@enron.com  kaminski-v
# 131928        shirley.crenshaw@enron.com  kaminski-v
# 131929          vince.kaminski@enron.com  kaminski-v
# 131930           rodrigo.lamas@enron.com  kaminski-v
# 131931        shirley.crenshaw@enron.com  kaminski-v
# 131932                zimin.lu@enron.com  kaminski-v
# 131933        shirley.crenshaw@enron.com  kaminski-v
# 131934          vince.kaminski@enron.com  kaminski-v
# 131935                     todd@epis.com  kaminski-v
# 131936          vince.kaminski@enron.com  kaminski-v
# 131937          vince.kaminski@enron.com  kaminski-v
# 131938                 vkaminski@aol.com  kaminski-v
# 131939          vince.kaminski@enron.com  kaminski-v
# 131940                 vkaminski@aol.com  kaminski-v
# 131941          clayton.vernon@enron.com  kaminski-v
# 131942           samer_takriti@enron.net  kaminski-v
# 131943          clayton.vernon@enron.com  kaminski-v
# 131946  0.092050  0.093445  0.093445       trust          1    Night
# 131947  0.101304  0.098295  0.092277    positive         14     Work
# 131948  0.098675  0.088365  0.097202    positive         11     Work
# 131949  0.099526  0.087678  0.094787    positive         11     Work
# 131950  0.105769  0.088462  0.094231       trust          9     Work
# 131951  0.096386  0.102410  0.096386       trust         11     Work
# 131952  0.096317  0.093484  0.099150    positive          8    Night
# 131953  0.100000  0.093162  0.097436       trust          7    Night
# 131954  0.099298  0.093280  0.098295       trust         16     Work
# 131955  0.094017  0.092593  0.095442    positive         16     Work
# 131956  0.103825  0.092896  0.092896    positive         16     Work
# 131957  0.102564  0.100000  0.094872    positive         23    Night
# 131958  0.099585  0.089212  0.091286    positive          8    Night
# 131959  0.087940  0.095477  0.087940       trust          1    Night
# 131960  0.092199  0.092199  0.093617       trust         15     Work
# 131961  0.088083  0.093264  0.088083       trust         15     Work
# 131962  0.095161  0.098387  0.096774       trust         15     Work
# 131963  0.090730  0.096647  0.092702    positive         15     Work
# 131964  0.094937  0.099684  0.096519       trust          1    Night
# 131965  0.099092  0.093041  0.096067       trust          8    Night
# 131966  0.090737  0.098299  0.092628    positive          1    Night
# 131967  0.106171  0.091652  0.088929    negative         10     Work
# 131968  0.093023  0.090909  0.097252    positive         17     Work
# 131969  0.105932  0.101695  0.093220    negative          9     Work
# 131970  0.100279  0.086351  0.097493       trust          8    Night
# 131971  0.097122  0.097122  0.097122    positive          3    Night
# 131972  0.094624  0.094624  0.096774       trust         11     Work
# 131973  0.093366  0.095823  0.098280    positive         10     Work
# 131974  0.101887  0.083019  0.090566       trust         21  Evening
#
# [193 rows x 25 columns]

# %%
HR.to_csv('hr.csv', index=False)
KPMG.to_csv('kpmg.csv', index=False)
Management.to_csv('management.csv', index=False)
Resume.to_csv('resume.csv', index=False)
IT.to_csv('it.csv', index=False)
Friends.to_csv('friends.csv', index=False)
Personal.to_csv('personal.csv', index=False)
Interviews.to_csv('interview.csv', index=False)
Federal.to_csv('federal.csv', index = False)

# %%
HR.Work.value_counts(normalize=True)
# Out:
# Night      0.432432
# Evening    0.389189
# Work       0.178378
# Name: Work, dtype: float64

# %%
## Selected folders for deployment purpose

Folder_selected = ['hr', 'kpmg', 'management', 'resume', 'it', 'friends', 'personalfolder', 'interview', 'federal', 'personal']

# %%
df_folder.loc[df_folder['X-Folder'] == 'management']
# Out:
# Empty DataFrame
# Columns: [email-body, From, employee, Date, Subject, X-Folder, To, X-cc, X-Origin, year, subjectivity , polarity, fear, anger, anticip, trust, surprise, positive, negative, sadness, disgust, joy, topemotion, time_hour, Work]
# Index: []
#
# [0 rows x 25 columns]

# %%
### making one common dataset for all selected folders

df_folder = pd.concat(map(pd.read_csv, ['folder/hr.csv', 'folder/kpmg.csv','folder/it.csv', 'folder/resume.csv', 'folder/management.csv', 'folder/friends.csv', 'folder/personal.csv', 'folder/interview.csv', 'folder/federal.csv', 'folder/prsnl.csv']))

# %%
df_folder.shape
# Out:
# (2725, 25)

# %%
df_folder
# Out:
#                                                                                                email-body  \
# 0     mary.solmonson@enron.com, martha.stevens@enron.com, robert.superty@enron.com, edward.terry@enron...
# 1     Content-Transfer-Encoding: 7bit Bcc: exec.jones@enron.com, tim.o'rourke@enron.com, mary.joyce@en...
# 2     X-bcc: X-Folder: \Steven_Kean_Jan2002\Kean, Steven J.\HR X-Origin: Harris-S X-FileName: sharris1...
# 3     billy.lemmons@enron.com, norman.levine@enron.com, drew.lynch@enron.com, cindy.olson@enron.com, t...
# 4     Content-Transfer-Encoding: quoted-printable Bcc: steven.kean@enron.com X-From: Kathy McMahon X-T...
# ...                                                                                                   ...
# 1306   Hey check these out dude. The Smashing Pumkins song is Drown and I can't find it on any other c...
# 1307   Hey let's go get coffee again that was really fun. I'm so much more awake now. When will you be...
# 1308                    You are cracking me up. Basically you are the only thing keeping me awake today..
# 1309   So what's the situation? You swamped? Under pressure? Did some shit hit the fan or what? It mig...
# 1310   Bill,  How's your day going? You seem busy and/or pre-occupied. Do you still wanna go get some ...
#
#                              From     employee                       Date  \
# 0     hector.mcloughlin@enron.com       beck-s  2001-04-04 01:52:00+00:00
# 1           david.oxley@enron.com       kean-s  2001-12-05 17:20:42+00:00
# 2         sheila.walton@enron.com       kean-s  2001-12-14 00:43:21+00:00
# 3         norman.levine@enron.com       kean-s  2001-09-26 20:50:04+00:00
# 4         kathy.mcmahon@enron.com       kean-s  2001-04-09 14:31:00+00:00
# ...                           ...          ...                        ...
# 1306       crystal.hyde@enron.com  williams-w3  2001-04-17 00:21:00+00:00
# 1307       crystal.hyde@enron.com  williams-w3  2001-04-05 03:25:00+00:00
# 1308       crystal.hyde@enron.com  williams-w3  2001-04-05 02:44:00+00:00
# 1309       crystal.hyde@enron.com  williams-w3  2001-04-05 02:42:00+00:00
# 1310       crystal.hyde@enron.com  williams-w3  2001-04-05 02:34:00+00:00
#
#                                          Subject  X-Folder  \
# 0                                 Action Request        hr
# 1     New HR Contacts - post headcount reduction        hr
# 2                                     New HR Rep        hr
# 3       Enron HR Newsletter - September 26, 2001        hr
# 4             PLEASE READ - HR Commercialization        hr
# ...                                          ...       ...
# 1306                              Singles Debate  personal
# 1307                           yummy frappachino  personal
# 1308                                Re: No Java?  personal
# 1309                                Re: No Java?  personal
# 1310                                    No Java?  personal
#
#                                                                                                        To  \
# 0     sally.beck@enron.com, thresa.allen@enron.com, bryce.baxter@enron.com, \n\tlinda.bryan@enron.com,...
# 1     kenneth.lay@enron.com, greg.whalley@enron.com, jim.fallon@enron.com, \n\tjohn.lavorato@enron.com...
# 2     j..kean@enron.com, elizabeth.linnell@enron.com, bill.donovan@enron.com, \n\tjohn.brindle@enron.c...
# 3     felecia.acevedo@enron.com, marla.barnard@enron.com, cynthia.barrow@enron.com, \n\tmelissa.becker...
# 4     marla.barnard@enron.com, cynthia.barrow@enron.com, suzanne.brown@enron.com, \n\ttimothy.callahan...
# ...                                                                                                   ...
# 1306                                                                                   bill.iii@enron.com
# 1307                                                                                   bill.iii@enron.com
# 1308                                                                                   bill.iii@enron.com
# 1309                                                                                   bill.iii@enron.com
# 1310                                                                                   bill.iii@enron.com
#
#                                                                                                      X-cc  \
# 0     Sunjay Arya <Sunjay Arya/ENRON@enronXgate>, John Blaylock <John Blaylock/ENRON@enronXgate>, Fran...
# 1     Jones, Robert W.- HR Exec </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Rjones2>, O'rourke, Tim </O=ENRON/OU=...
# 2     McVicker, Maureen </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Mmcvick>, De Jesus, Frank </O=ENRON/OU=NA/CN=...
# 3                                                                                                     NaN
# 4                                                                                           Steven J Kean
# ...                                                                                                   ...
# 1306                                                                                                  NaN
# 1307                                                                                                  NaN
# 1308                                                                                                  NaN
# 1309                                                                                                  NaN
# 1310                                                                                                  NaN
#
#          X-Origin  year  ...     trust  surprise  positive  negative  \
# 0          BECK-S  2001  ...  0.113872  0.086957  0.118012  0.113872
# 1        Harris-S  2001  ...  0.108642  0.083951  0.111111  0.113580
# 2        Harris-S  2001  ...  0.122302  0.093525  0.107914  0.100719
# 3          Kean-S  2001  ...  0.103774  0.066038  0.113208  0.122642
# 4          KEAN-S  2001  ...  0.113636  0.086364  0.119697  0.106061
# ...           ...   ...  ...       ...       ...       ...       ...
# 1306  WILLIAMS-W3  2001  ...  0.116667  0.083333  0.116667  0.100000
# 1307  WILLIAMS-W3  2001  ...  0.106742  0.084270  0.117978  0.106742
# 1308  WILLIAMS-W3  2001  ...  0.142857  0.071429  0.178571  0.142857
# 1309  WILLIAMS-W3  2001  ...  0.091549  0.091549  0.098592  0.105634
# 1310  WILLIAMS-W3  2001  ...  0.104575  0.091503  0.117647  0.098039
#
#        sadness   disgust       joy  topemotion  time_hour     Work
# 0     0.095238  0.095238  0.086957    positive          1    Night
# 1     0.098765  0.093827  0.091358    negative         17     Work
# 2     0.100719  0.093525  0.093525       trust          0    Night
# 3     0.084906  0.132075  0.075472     disgust         20  Evening
# 4     0.095455  0.089394  0.101515    positive         14     Work
# ...        ...       ...       ...         ...        ...      ...
# 1306  0.100000  0.100000  0.100000       trust          0    Night
# 1307  0.095506  0.101124  0.106742    positive          3    Night
# 1308  0.107143  0.107143  0.071429    positive          2    Night
# 1309  0.105634  0.098592  0.091549        fear          2    Night
# 1310  0.091503  0.091503  0.111111    positive          2    Night
#
# [2532 rows x 25 columns]

# %%
##  Ploting stress level over the years ---- (plotly)

df_folder.groupby("year")["Work"].value_counts(normalize = True).plot.barh()

# %%
## making csv for subset of folder file for deployment

df_folder.to_csv('df_folder.csv', index = False)

# %%
## making  wordcloud universal function only for selected folders 

from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from nltk.corpus import stopwords
import wordcloud


def WC_Folder(Folder, stpwords = None):
    
    data = df_folder.loc[df_folder['X-Folder'] == Folder]
     
    
    stop_words = stopwords.words('english')
    
    list_stpwords = ['enron', 'com', 're', 'RECIPIENTS', 'CN', 'ENRON', 'OU', 'NA', 'Thank', 'mail', 'know', 'get', 'Thanks', 'one', 'let', 'cc', 'bc', 'subject', 'http', 'www', 'hotmail', 'email', 'would', 'back', 'time', 'bcc','new', 'aol', 'Com', 'Original Message','message']
    
    if stpwords is True:
        
         list_stpwords.append(stpwords) 
        
        
    stop_words.extend(list_stpwords)

    subjects = ' '.join(data['email-body'])

    fig, ax = plt.subplots(figsize=(16, 12))

    wc = wordcloud.WordCloud(width=800, 
                             height=600, 
                             max_words=200,
                             stopwords=stop_words).generate(subjects)
    ax.imshow(wc)
    ax.axis("off")
    
    plot = ax.imshow(wc)
    
    return plot

# %%
WC_Folder('management')

# %%
df_folder.head(2)
# Out:
#                                                                                             email-body  \
# 0  mary.solmonson@enron.com, martha.stevens@enron.com, robert.superty@enron.com, edward.terry@enron...
# 1  Content-Transfer-Encoding: 7bit Bcc: exec.jones@enron.com, tim.o'rourke@enron.com, mary.joyce@en...
#
#                           From employee                       Date  \
# 0  hector.mcloughlin@enron.com   beck-s  2001-04-04 01:52:00+00:00
# 1        david.oxley@enron.com   kean-s  2001-12-05 17:20:42+00:00
#
#                                       Subject X-Folder  \
# 0                              Action Request       hr
# 1  New HR Contacts - post headcount reduction       hr
#
#                                                                                                     To  \
# 0  sally.beck@enron.com, thresa.allen@enron.com, bryce.baxter@enron.com, \n\tlinda.bryan@enron.com,...
# 1  kenneth.lay@enron.com, greg.whalley@enron.com, jim.fallon@enron.com, \n\tjohn.lavorato@enron.com...
#
#                                                                                                   X-cc  \
# 0  Sunjay Arya <Sunjay Arya/ENRON@enronXgate>, John Blaylock <John Blaylock/ENRON@enronXgate>, Fran...
# 1  Jones, Robert W.- HR Exec </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Rjones2>, O'rourke, Tim </O=ENRON/OU=...
#
#    X-Origin  year  ...     trust  surprise  positive  negative   sadness  \
# 0    BECK-S  2001  ...  0.113872  0.086957  0.118012  0.113872  0.095238
# 1  Harris-S  2001  ...  0.108642  0.083951  0.111111  0.113580  0.098765
#
#     disgust       joy  topemotion  time_hour   Work
# 0  0.095238  0.086957    positive          1  Night
# 1  0.093827  0.091358    negative         17   Work
#
# [2 rows x 25 columns]

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
fig = go.Figure(go.Scattergl(IT, x = 'time_hour', y = 'topemotion', title='Emotion hourly based work '))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-1c2e0ab23eea> in <module>
# ----> 1 fig = go.Figure(go.Scattergl(IT, x = 'time_hour', y = 'topemotion', title='Emotion hourly based work '))
#       2 fig.show()
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/graph_objs/_scattergl.py in __init__(self, arg, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legendgroup, line, marker, meta, metasrc, mode, name, opacity, selected, selectedpoints, showlegend, stream, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, x, x0, xaxis, xcalendar, xsrc, y, y0, yaxis, ycalendar, ysrc, **kwargs)
#    2247             arg = _copy.copy(arg)
#    2248         else:
# -> 2249             raise ValueError(
#    2250                 """\
#    2251 The first argument to the plotly.graph_objs.Scattergl
#
# ValueError: The first argument to the plotly.graph_objs.Scattergl
# constructor must be a dict or
# an instance of :class:`plotly.graph_objs.Scattergl`

# %%
df_folder.groupby("year")["topemotion"].value_counts(normalize = True).plot.bar()

# %%
df_folder.groupby('year').topemotion.value_counts(normalize= True).unstack(0).plot.bar()

# %%
df_folder.groupby('Work').topemotion.value_counts(normalize = True).unstack(0).plot.bar()

# %%
HR.groupby('Work').topemotion.value_counts(normalize = True).unstack(0).plot.bar()

# %%
def plot(Folder):
    
    data = df_folder.loc[df_folder['X-Folder'] == Folder]
    
    data.groupby('year').topemotion.value_counts(normalize = True).unstack(0).plot.bar()
    
    data.groupby('year').time_hour.value_counts(normalize = True).unstack(0).plot.bar()
    
    data.groupby('year').Work.value_counts(normalize = True).unstack(0).plot.bar()

# %%
df_folder.groupby('year').Work.value_counts(normalize = True).unstack(0).plot.bar()
