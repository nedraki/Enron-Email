# %%
#immporting libraries

import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import os
import pandas_bokeh

# %%
#prompt for user input of year

# year = input("Please enter year of interest: ")

# # read in the csv for the correct year

# filepath = "Enron_" + year +".csv"
# print(filepath)

# filepath = os.path.abspath('../data/Enron_Kaggle_dataset/Enron_2000.csv') # Subset with 1K Random Emails
filepath = os.path.abspath('../data/Enron_Kaggle_dataset/score.csv') # Full set

df = pd.read_csv(filepath)

# %%
df.head()
# Out:
#                                           email-body                     From  \
# 0                             Here is our forecast    phillip.allen@enron.com
# 1   Traveling to have a business meeting takes th...  phillip.allen@enron.com
# 2                     test successful.  way to go!!!  phillip.allen@enron.com
# 3   Randy,  Can you send me a schedule of the sal...  phillip.allen@enron.com
# 4                  Let's shoot for Tuesday at 11:45.  phillip.allen@enron.com
#
#   employee                       Date    Subject    X-Folder  \
# 0  allen-p  2001-05-14 23:39:00+00:00        NaN  'sent mail
# 1  allen-p  2001-05-04 20:51:00+00:00        Re:  'sent mail
# 2  allen-p  2000-10-18 10:00:00+00:00   Re: test  'sent mail
# 3  allen-p  2000-10-23 13:13:00+00:00        NaN  'sent mail
# 4  allen-p  2000-08-31 12:07:00+00:00  Re: Hello  'sent mail
#
#                         To X-cc X-Origin  year  ...     anger   anticip  \
# 0     tim.belden@enron.com  NaN  Allen-P  2001  ...  0.100000  0.100000
# 1  john.lavorato@enron.com  NaN  Allen-P  2001  ...  0.094070  0.096115
# 2   leah.arsdall@enron.com  NaN  Allen-P  2000  ...  0.083333  0.111111
# 3    randall.gay@enron.com  NaN  Allen-P  2000  ...  0.095238  0.095238
# 4     greg.piper@enron.com  NaN  Allen-P  2000  ...  0.250000  0.000000
#
#       trust  surprise  positive  negative   sadness   disgust       joy  \
# 0  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 1  0.106339  0.089980  0.114519  0.104294  0.100204  0.096115  0.100204
# 2  0.111111  0.083333  0.111111  0.111111  0.111111  0.083333  0.111111
# 3  0.142857  0.095238  0.095238  0.095238  0.095238  0.095238  0.095238
# 4  0.000000  0.000000  0.250000  0.250000  0.000000  0.000000  0.000000
#
#    topemotion
# 0        fear
# 1    positive
# 2     anticip
# 3       trust
# 4        fear
#
# [5 rows x 23 columns]

# %%
def plot_hr_metrics(dataset):
    #converting the Date column into datetime type
    df["Date"] = pd.to_datetime(df["Date"])
    scatter = px.scatter(df.groupby(["employee"])["Date"].min().sort_values())

    ### Layout for figure:

    scatter.update_layout(
        title="First mail sent",
        xaxis_title="Employee",
        yaxis_title="Date",
        legend_title="Legend",
        xaxis =  {'showgrid': False},
        yaxis = {'showgrid': True})

    return scatter

# %%
def plot_hiring(year_of_interest):

    filepath = 'data/Enron_by_year.csv' # 3K emails
    df = pd.read_csv(filepath)

    #Converting the Date column into datetime type
    
    df["Date"] = pd.to_datetime(df["Date"])

    #Select year: 

    df = df.loc[df['year'] == year_of_interest]

    scatter = px.scatter(df.groupby(["employee"])["Date"].min().sort_values())

    ### Layout for figure:

    scatter.update_layout(
        title="First mail sent",
        xaxis_title="Employee",
        yaxis_title="Date",
        legend_title="Legend",
        xaxis =  {'showgrid': False},
        yaxis = {'showgrid': True})

    return scatter

# %%
fig = plot_hiring(2000)
# Out:
# ----------------------------------------------------------------------
# FileNotFoundError                    Traceback (most recent call last)
# <ipython-input-9-cb5dc32c2e95> in <module>
# ----> 1 fig = plot_hiring(2000)
#
# <ipython-input-8-310b2e0bf810> in plot_hiring(year_of_interest)
#       2
#       3     filepath = 'data/Enron_by_year.csv' # 3K emails
# ----> 4     df = pd.read_csv(filepath)
#       5
#       6     #Converting the Date column into datetime type
#
# ~/anaconda3/envs/NLP/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/anaconda3/envs/NLP/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/anaconda3/envs/NLP/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~/anaconda3/envs/NLP/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~/anaconda3/envs/NLP/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Enron_by_year.csv'

# %%
year_of_interest =2001
df["Date"] = pd.to_datetime(df["Date"])
#Select year: 
df = df.loc[df['year'] == year_of_interest]
add_data = df.groupby(["employee"])["Date"].min().sort_values()


# Add traces
fig.add_trace(go.Scatter(add_data,
                    mode='markers',
                    name='markers'))

# %%
# fig = plot_hiring(2000)


# # Add traces
# fig.add_trace(go.Scatter(,
#                     mode='markers',
#                     name='markers'))
# fig.add_trace(go.Scatter(x=random_x, y=random_y1,
#                     mode='lines+markers',
#                     name='lines+markers'))
# fig.add_trace(go.Scatter(x=random_x, y=random_y2,
#                     mode='lines',
#                     name='lines'))

# %%
df = df.groupby(["employee"], as_index=False)["Date" == 2000].min() dkdk

# %%
df['month'] = pd.DatetimeIndex(df['Date']).month
df['year'] = pd.DatetimeIndex(df['Date']).year
df

# %%
import plotly.express as px
fig = px.line(df, x='employee', y='month', color='year')
fig.show()
